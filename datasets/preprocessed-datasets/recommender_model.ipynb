# %%
import requests
import json
import requests
import pandas as pd
from plotly import graph_objects as go
import plotly.graph_objects as go
import numpy as np
import plotly.express as px

# %%
# %run merge_data.ipynb
# %run trips_duration.ipynb
# Out:
# [{'OBS_VALUE': '68.3737', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': 'Euromonitor road network data divided by land area', 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': True, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_ROADDENS', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2024', 'FREQ': 'A', 'UNIT_MEASURE': 'KM', 'UNIT_TYPE': None}, {'OBS_VALUE': '3.05121', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': 'Euromonitor road network data divided by land area', 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': True, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_ROADDENS', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2024', 'FREQ': 'A', 'UNIT_MEASURE': 'KM', 'UNIT_TYPE': None}, {'OBS_VALUE': '48', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': 'Euromonitor road network data divided by land area', 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': True, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_ROADDENS', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2024', 'FREQ': 'A', 'UNIT_MEASURE': 'KM', 'UNIT_TYPE': None}, {'OBS_VALUE': '68.0339', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': 'Euromonitor road network data divided by land area', 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': False, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_ROADDENS', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2021', 'FREQ': 'A', 'UNIT_MEASURE': 'KM', 'UNIT_TYPE': None}, {'OBS_VALUE': '3.04102', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': 'Euromonitor road network data divided by land area', 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': False, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_ROADDENS', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2021', 'FREQ': 'A', 'UNIT_MEASURE': 'KM', 'UNIT_TYPE': None}, {'OBS_VALUE': '48', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': 'Euromonitor road network data divided by land area', 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': False, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_ROADDENS', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2021', 'FREQ': 'A', 'UNIT_MEASURE': 'KM', 'UNIT_TYPE': None}, {'OBS_VALUE': '67.6781', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': 'Euromonitor road network data divided by land area', 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': False, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_ROADDENS', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2019', 'FREQ': 'A', 'UNIT_MEASURE': 'KM', 'UNIT_TYPE': None}, {'OBS_VALUE': '3.03034', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, ' ...
# [{'OBS_VALUE': '1.76106', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': None, 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': True, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_FUELPRICE', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2024', 'FREQ': 'A', 'UNIT_MEASURE': 'USD', 'UNIT_TYPE': None}, {'OBS_VALUE': '2.31681', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': None, 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': True, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_FUELPRICE', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2024', 'FREQ': 'A', 'UNIT_MEASURE': 'USD', 'UNIT_TYPE': None}, {'OBS_VALUE': '97', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': None, 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': True, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_FUELPRICE', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2024', 'FREQ': 'A', 'UNIT_MEASURE': 'USD', 'UNIT_TYPE': None}, {'OBS_VALUE': '1.66', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': None, 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': False, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_FUELPRICE', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2021', 'FREQ': 'A', 'UNIT_MEASURE': 'USD', 'UNIT_TYPE': None}, {'OBS_VALUE': '2.275', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': None, 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': False, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_FUELPRICE', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2021', 'FREQ': 'A', 'UNIT_MEASURE': 'USD', 'UNIT_TYPE': None}, {'OBS_VALUE': '99', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': None, 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': False, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_FUELPRICE', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2021', 'FREQ': 'A', 'UNIT_MEASURE': 'USD', 'UNIT_TYPE': None}, {'OBS_VALUE': '1.66', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': None, 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': False, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_FUELPRICE', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL', 'COMP_BREAKDOWN_2': '_Z', 'COMP_BREAKDOWN_3': '_Z', 'TIME_PERIOD': '2019', 'FREQ': 'A', 'UNIT_MEASURE': 'USD', 'UNIT_TYPE': None}, {'OBS_VALUE': '2.275', 'TIME_FORMAT': '602', 'UNIT_MULT': 0, 'COMMENT_OBS': None, 'OBS_STATUS': 'A', 'OBS_CONF': 'PU', 'AGG_METHOD': None, 'DECIMALS': None, 'COMMENT_TS': None, 'DATA_SOURCE': None, 'LATEST_DATA': False, 'DATABASE_ID': 'WEF_TTDI', 'INDICATOR': 'WEF_TTDI_FUELPRICE', 'REF_AREA': 'ALB', 'SEX': '_T', 'AGE': '_T', 'URBANISATION': '_T', 'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR', 'COMP_BRE ...
# 6765
# Requirement already satisfied: kaleido in /Users/mariasamosrivas/Desktop/NEU/DS3000/anaconda3/lib/python3.12/site-packages (0.2.1)
# Note: you may need to restart the kernel to use updated packages.
#   File /var/folders/6f/26l7p7y90rd4sw3bc17185400000gn/T/ipykernel_84366/618003627.py:10
#     alldata_density.sort_values(by = ["Country", "Year"])\
#                                                           ^
# SyntaxError: incomplete input
# Traceback (most recent call last):
#
#   File ~/Desktop/NEU/DS3000/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[7], line 1
#     get_ipython().run_line_magic('run', 'merge_data.ipynb')
#
#   File ~/Desktop/NEU/DS3000/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2480 in run_line_magic
#     result = fn(*args, **kwargs)
#
#   File ~/Desktop/NEU/DS3000/anaconda3/lib/python3.12/site-packages/IPython/core/magics/execution.py:737 in run
#     self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#
#   File ~/Desktop/NEU/DS3000/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3005 in safe_execfile_ipy
#     result.raise_error()
#
#   File ~/Desktop/NEU/DS3000/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:306 in raise_error
#     raise self.error_before_exec
#
#   File ~/Desktop/NEU/DS3000/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3306 in run_cell_async
#     code_ast = compiler.ast_parse(cell, filename=cell_name)
#
#   File ~/Desktop/NEU/DS3000/anaconda3/lib/python3.12/site-packages/IPython/core/compilerop.py:86 in ast_parse
#     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
#   File /var/folders/6f/26l7p7y90rd4sw3bc17185400000gn/T/ipykernel_84366/618003627.py:10
#     alldata_density.sort_values(by = ["Country", "Year"])\
#                                                           ^
# SyntaxError: incomplete input

# %%
df_merged 
fuel = df_merged[["Fuel Score"]].astype(float)
Fuel_standardize = (fuel -1) / (7-1)
density = df_merged[["Density Score"]].astype(float)
Density_standardize = (density -1) / (7-1)
df_merged["Fuel Score St."] = Fuel_standardize
df_merged["Density Score St."] = Density_standardize
df_merged_standardized = pd.DataFrame(df_merged, columns = ["Country", "Year", "Fuel Score St.", "Density Score St."])
df_merged_standardized['Year'] = df_merged_standardized['Year'].astype(int)    
df_merged_standardized
# Out:
#     Country  Year  Fuel Score St.  Density Score St.
# 0   Austria  2019        0.382700           0.772715
# 1   Austria  2021        0.304340           0.775648
# 2   Austria  2024        0.227270           0.749753
# 3   Belgium  2019        0.269300           1.000000
# 4   Belgium  2021        0.152768           1.000000
# ..      ...   ...             ...                ...
# 76    Spain  2021        0.234838           0.667055
# 77    Spain  2024        0.215143           0.667012
# 78   Sweden  2019        0.209655           0.539033
# 79   Sweden  2021        0.059442           0.528167
# 80   Sweden  2024        0.151893           0.530147
#
# [81 rows x 4 columns]

# %%
df_merged_standardized.loc[df_merged_standardized['Country'] == 'Slovak Republic', 'Country'] = 'Slovakia'
df_merged_standardized['Country'].unique()
# Out:
# array(['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia',
#        'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece',
#        'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Malta', 'Netherlands', 'Poland', 'Portugal', 'Romania',
#        'Slovakia', 'Slovenia', 'Spain', 'Sweden'], dtype=object)

# %%
fuel_density_2019 = df_merged_standardized[df_merged_standardized['Year'] == 2019]
fuel_density_2019
fuel_density_2019['Country'].unique()
# Out:
# array(['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia',
#        'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece',
#        'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Malta', 'Netherlands', 'Poland', 'Portugal', 'Romania',
#        'Slovakia', 'Slovenia', 'Spain', 'Sweden'], dtype=object)

# %%
final_1plus_df
# Out:
#               Purpose         Duration      Country  Year  NumTrips
# 0    Personal Reasons  1 night or over      Albania  2017   8186685
# 1    Personal Reasons  1 night or over      Albania  2019  10176614
# 2    Personal Reasons  1 night or over      Albania  2020   6624361
# 3    Personal Reasons  1 night or over      Austria  2012  36003256
# 4    Personal Reasons  1 night or over      Austria  2013  36479782
# ..                ...              ...          ...   ...       ...
# 345  Personal Reasons  1 night or over  Switzerland  2018  40810491
# 346  Personal Reasons  1 night or over  Switzerland  2019  36986339
# 347  Personal Reasons  1 night or over  Switzerland  2020  31748407
# 348  Personal Reasons  1 night or over  Switzerland  2021  32989206
# 349  Personal Reasons  1 night or over  Switzerland  2022  46256337
#
# [350 rows x 5 columns]

# %%
trips_2019 = final_1plus_df[final_1plus_df['Year'] == 2019]
trips_2019 = trips_2019[~trips_2019['Country'].isin([
    'European Union - 27 countries (from 2020)',
    'Albania',
    'Switzerland',
    'North Macedonia'
])]

trips_2019
# Out:
#               Purpose         Duration      Country  Year   NumTrips
# 10   Personal Reasons  1 night or over      Austria  2019   42415052
# 22   Personal Reasons  1 night or over      Belgium  2019   33680649
# 34   Personal Reasons  1 night or over     Bulgaria  2019    9477196
# 46   Personal Reasons  1 night or over      Croatia  2019   10251772
# 58   Personal Reasons  1 night or over       Cyprus  2019    5753450
# 70   Personal Reasons  1 night or over      Czechia  2019   66969988
# 82   Personal Reasons  1 night or over      Denmark  2019   52037652
# 94   Personal Reasons  1 night or over      Estonia  2019    8753307
# 106  Personal Reasons  1 night or over      Finland  2019   66165686
# 118  Personal Reasons  1 night or over       France  2019  386709202
# 130  Personal Reasons  1 night or over      Germany  2019  439169070
# 142  Personal Reasons  1 night or over       Greece  2019   11562642
# 154  Personal Reasons  1 night or over      Hungary  2019   38102812
# 166  Personal Reasons  1 night or over      Ireland  2019   31378452
# 178  Personal Reasons  1 night or over        Italy  2019  109077864
# 190  Personal Reasons  1 night or over       Latvia  2019    7457030
# 202  Personal Reasons  1 night or over    Lithuania  2019    8598280
# 214  Personal Reasons  1 night or over   Luxembourg  2019    4143074
# 226  Personal Reasons  1 night or over        Malta  2019    1570905
# 240  Personal Reasons  1 night or over  Netherlands  2019   85166693
# 264  Personal Reasons  1 night or over       Poland  2019  121249320
# 276  Personal Reasons  1 night or over     Portugal  2019   37152910
# 288  Personal Reasons  1 night or over      Romania  2019   37503804
# 301  Personal Reasons  1 night or over     Slovakia  2019   24106768
# 313  Personal Reasons  1 night or over     Slovenia  2019    8610043
# 325  Personal Reasons  1 night or over        Spain  2019  291426796
# 335  Personal Reasons  1 night or over       Sweden  2019   89854108

# %%
min_trips = trips_2019['NumTrips'].min()
max_trips = trips_2019['NumTrips'].max()

trips_2019['Tourism St.'] = (trips_2019['NumTrips'] - min_trips) / (max_trips - min_trips)

# %%
trips_2019.drop(columns = ['NumTrips', 'Duration'])
trips_2019['Country'].unique()
# Out:
# array(['Austria', 'Belgium', 'Bulgaria', 'Croatia', 'Cyprus', 'Czechia',
#        'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece',
#        'Hungary', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Malta', 'Netherlands', 'Poland', 'Portugal', 'Romania',
#        'Slovakia', 'Slovenia', 'Spain', 'Sweden'], dtype=object)

# %%
recommender_data = pd.merge(fuel_density_2019, trips_2019, on = ['Country', 'Year'])
recommender_data
# Out:
#         Country  Year  Fuel Score St.  Density Score St.           Purpose  \
# 0       Austria  2019        0.382700           0.772715  Personal Reasons
# 1       Belgium  2019        0.269300           1.000000  Personal Reasons
# 2      Bulgaria  2019        0.491080           0.187095  Personal Reasons
# 3       Croatia  2019        0.344223           0.238313  Personal Reasons
# 4        Cyprus  2019        0.417000           0.709565  Personal Reasons
# 5       Czechia  2019        0.372012           0.836563  Personal Reasons
# 6       Denmark  2019        0.141125           0.934100  Personal Reasons
# 7       Estonia  2019        0.314100           0.688268  Personal Reasons
# 8       Finland  2019        0.193000           0.128237  Personal Reasons
# 9        France  2019        0.195800           1.000000  Personal Reasons
# 10      Germany  2019        0.264400           0.920948  Personal Reasons
# 11       Greece  2019        0.128600           0.457180  Personal Reasons
# 12      Hungary  2019        0.426402           1.000000  Personal Reasons
# 13      Ireland  2019        0.267900           0.717692  Personal Reasons
# 14        Italy  2019        0.149600           0.840430  Personal Reasons
# 15       Latvia  2019        0.380600           0.564368  Personal Reasons
# 16    Lithuania  2019        0.443600           0.683482  Personal Reasons
# 17   Luxembourg  2019        0.401600           1.000000  Personal Reasons
# 18        Malta  2019        0.284000           1.000000  Personal Reasons
# 19  Netherlands  2019        0.097100           1.000000  Personal Reasons
# 20       Poland  2019        0.436765           0.693278  Personal Reasons
# 21     Portugal  2019        0.205600           0.464300  Personal Reasons
# 22      Romania  2019        0.435555           0.187383  Personal Reasons
# 23     Slovakia  2019        0.322500           0.470255  Personal Reasons
# 24     Slovenia  2019        0.351900           1.000000  Personal Reasons
# 25        Spain  2019        0.344200           0.667213  Personal Reasons
# 26       Sweden  2019        0.209655           0.539033  Personal Reasons
#
#            Duration   NumTrips  Tourism St.
# 0   1 night or over   42415052     0.093337
# 1   1 night or over   33680649     0.073377
# 2   1 night or over    9477196     0.018067
# 3   1 night or over   10251772     0.019838
# 4   1 night or over    5753450     0.009558
# 5   1 night or over   66969988     0.149450
# 6   1 night or over   52037652     0.115327
# 7   1 night or over    8753307     0.016413
# 8   1 night or over   66165686     0.147612
# 9   1 night or over  386709202     0.880119
# 10  1 night or over  439169070     1.000000
# 11  1 night or over   11562642     0.022833
# 12  1 night or over   38102812     0.083483
# 13  1 night or over   31378452     0.068116
# 14  1 night or over  109077864     0.245675
# 15  1 night or over    7457030     0.013451
# 16  1 night or over    8598280     0.016059
# 17  1 night or over    4143074     0.005878
# 18  1 night or over    1570905     0.000000
# 19  1 night or over   85166693     0.191033
# 20  1 night or over  121249320     0.273489
# 21  1 night or over   37152910     0.081312
# 22  1 night or over   37503804     0.082114
# 23  1 night or over   24106768     0.051499
# 24  1 night or over    8610043     0.016086
# 25  1 night or over  291426796     0.662379
# 26  1 night or over   89854108     0.201745

# %%
# FINAL DATA TO BE USED FOR FIRST ML MODEL!!!!!
# MARIA AND GABBY ARE SO SO HAPPY ON 6/5/2025 (gabbys birthday!) at 1:43 am!!!!!
recommender_data = pd.DataFrame(recommender_data, columns = ['Country', 'Year', 'Fuel Score St.', 'Density Score St.', 'Tourism St.'])
recommender_data
# Out:
#         Country  Year  Fuel Score St.  Density Score St.  Tourism St.
# 0       Austria  2019        0.382700           0.772715     0.093337
# 1       Belgium  2019        0.269300           1.000000     0.073377
# 2      Bulgaria  2019        0.491080           0.187095     0.018067
# 3       Croatia  2019        0.344223           0.238313     0.019838
# 4        Cyprus  2019        0.417000           0.709565     0.009558
# 5       Czechia  2019        0.372012           0.836563     0.149450
# 6       Denmark  2019        0.141125           0.934100     0.115327
# 7       Estonia  2019        0.314100           0.688268     0.016413
# 8       Finland  2019        0.193000           0.128237     0.147612
# 9        France  2019        0.195800           1.000000     0.880119
# 10      Germany  2019        0.264400           0.920948     1.000000
# 11       Greece  2019        0.128600           0.457180     0.022833
# 12      Hungary  2019        0.426402           1.000000     0.083483
# 13      Ireland  2019        0.267900           0.717692     0.068116
# 14        Italy  2019        0.149600           0.840430     0.245675
# 15       Latvia  2019        0.380600           0.564368     0.013451
# 16    Lithuania  2019        0.443600           0.683482     0.016059
# 17   Luxembourg  2019        0.401600           1.000000     0.005878
# 18        Malta  2019        0.284000           1.000000     0.000000
# 19  Netherlands  2019        0.097100           1.000000     0.191033
# 20       Poland  2019        0.436765           0.693278     0.273489
# 21     Portugal  2019        0.205600           0.464300     0.081312
# 22      Romania  2019        0.435555           0.187383     0.082114
# 23     Slovakia  2019        0.322500           0.470255     0.051499
# 24     Slovenia  2019        0.351900           1.000000     0.016086
# 25        Spain  2019        0.344200           0.667213     0.662379
# 26       Sweden  2019        0.209655           0.539033     0.201745

# %%
def normalize_user_input(user_input):
    """
    Takes in user preferences on a 0-10 scale for:
    - fuel: importance on saving fuel prices
    - traffic: importance avoiding traffic
    - tourism: importance of avoiding high-tourism countries

    Returns: a normalized array on a 0-1 scale
    """
    max_scale = 10
    weights = np.array([
        user_input['fuel_price'] / max_scale,
        user_input['traffic_time'] / max_scale,
        user_input['tourism_num'] / max_scale
    ])
    return weights

# %%
# example input
user_input = {
    'fuel_price': 8,
    'traffic_time': 5,
    'tourism_num': 9
}

user_weights = normalize_user_input(user_input)
print(user_weights)
# Out:
# [0.8 0.5 0.9]

# %%
def compute_cosine_similarities(user_vector, country_vector):
    """
    Gets the cosine similarity between the user input and each country's vector.

    Returns: similarity score (float)
    """    
    dot_product = np.dot(user_vector, country_vector)
    user_norm = np.linalg.norm(user_vector)
    country_norm = np.linalg.norm(country_vector)

    # Prevent division by zero
    if user_norm == 0 or country_norm == 0:
        return 0

    return dot_product / (user_norm * country_norm)

# %%
def get_top_5_recommendations(user_input, recommender_data):
    """Recommends top 5 countries closest to user preferences based on cosine similarity."""

    user_vector = normalize_user_input(user_input)

    similarities = []

    for index, row in recommender_data.iterrows():
        country_vector = np.array([
            row["Fuel Score St."], 
            row["Density Score St."], 
            row["Tourism St."]
        ])

        similarity = compute_cosine_similarities(user_vector, country_vector)
        similarities.append((row["Country"], similarity))

    similarity_df = pd.DataFrame(similarities, columns=["Country", "Similarity"])
    top_5 = similarity_df.sort_values("Similarity", ascending=False).head(5)

    return top_5

# %%
user_input = {
    "fuel_price": 8,
    "traffic_time": 4,
    "tourism_num": 3
}

top_5 = pd.DataFrame(get_top_5_recommendations(user_input, recommender_data))
top_5
# Out:
#      Country  Similarity
# 22   Romania    0.986912
# 8    Finland    0.964457
# 2   Bulgaria    0.953758
# 3    Croatia    0.952560
# 20    Poland    0.869730

# %%
def map_visual(country_dataframe):
    eu_iso_codes = {
    "Austria": "AUT",
    "Belgium": "BEL",
    "Bulgaria": "BGR",
    "Croatia": "HRV",
    "Cyprus": "CYP",
    "Czechia": "CZE",
    "Denmark": "DNK",
    "Estonia": "EST",
    "Finland": "FIN",
    "France": "FRA",
    "Germany": "DEU",
    "Greece": "GRC",
    "Hungary": "HUN",
    "Ireland": "IRL",
    "Italy": "ITA",
    "Latvia": "LVA",
    "Lithuania": "LTU",
    "Luxembourg": "LUX",
    "Malta": "MLT",
    "Netherlands": "NLD",
    "Poland": "POL",
    "Portugal": "PRT",
    "Romania": "ROU",
    "Slovakia": "SVK",
    "Slovenia": "SVN",
    "Spain": "ESP",
    "Sweden": "SWE"
}
    country_dataframe["ISO"] = country_dataframe["Country"].map(eu_iso_codes)
    country_dataframe["Match Rating"] = country_dataframe["Similarity"]

    fig = px.choropleth(country_dataframe, locations="ISO",
                    color="Match Rating", 
                    locationmode='ISO-3',
                    hover_name = "Country", 
                    scope='europe',         
                    color_continuous_scale=px.colors.sequential.Teal, 
                    ) 
    fig.update_layout(
        margin = dict(l=10, r = 10, t = 35, b = 0), 
        width = 1000, 
        height = 800, 
        title = (f"Top 5 Recommended Countries"), 
    )
    fig.show()

# %%
map_visual(top_5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 map_visual(top_5)
#
# NameError: name 'top_5' is not defined

# %%
def empty_visual(country_dataframe): 
    fig = px.choropleth(
                    locationmode='ISO-3', 
                    scope='europe', 
                    ) 
    fig.update_layout(
        margin = dict(l=10, r = 10, t = 35, b = 0), 
        width = 1000, 
        height = 800, 
        title = (f"Top 5 Recommended Countries"), 
    )
    fig.show()

# %%
empty_visual(top_5)
