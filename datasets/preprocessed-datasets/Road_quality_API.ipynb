# %%
import requests
import json
import requests
import pandas as pd

# %%
EU_countries_list = [
    'Austria', "Belgium", "Bulgaria", "Croatia", "Cyprus", "Czechia",
    "Denmark", "Estonia", "Finland", "France", "Germany", "Greece", "Hungary",
    "Ireland", "Italy", "Latvia", "Lithuania", "Luxembourg", "Malta",
    "Netherlands", "Poland", "Portugal", "Romania", "Slovak Republic", "Slovenia",
    "Spain", "Sweden"
]

# %%
url = 'https://data360api.worldbank.org/data360/data?DATABASE_ID=WEF_TTDI&INDICATOR=WEF_TTDI_EOSQ057&skip=0'

# %%
text = requests.get(url).text    
data = json.loads(text)
data
# Out:
# {'count': 1071,
#  'value': [{'OBS_VALUE': '4.63314',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ALB',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '4.63314',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ALB',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '47',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ALB',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '4.06469',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ALB',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '4.06469',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ALB',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '72',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ALB',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '4.25518',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ALB',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '4.25518',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ALB',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '54',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ALB',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.69484',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'DZA',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.69484',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'DZA',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '87',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'DZA',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '4.03099',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'DZA',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '4.03099',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'DZA',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '75',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'DZA',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.56951',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'DZA',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.56951',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'DZA',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '80',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'DZA',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '2.34248',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'AGO',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '2.34248',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'AGO',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '119',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'AGO',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '2.31706',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'AGO',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '2.31706',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'AGO',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '119',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'AGO',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '2.07692',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'AGO',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '2.07692',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'AGO',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '119',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'AGO',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.54685',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARG',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.54685',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARG',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '91',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARG',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.60358',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARG',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.60358',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARG',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '94',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARG',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.43284',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARG',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.43284',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARG',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '86',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARG',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.86352',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARM',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.86352',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARM',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '80',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARM',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.89218',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARM',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.89218',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARM',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '83',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARM',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.62265',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARM',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '3.62265',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARM',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '79',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARM',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE':

#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2021',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '5.91808',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARE',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '5.91808',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARE',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_SCR',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '8',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': False,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'ARE',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_RNK',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2019',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None},
#   {'OBS_VALUE': '4.91482',
#    'TIME_FORMAT': '602',
#    'UNIT_MULT': 0,
#    'COMMENT_OBS': None,
#    'OBS_STATUS': 'A',
#    'OBS_CONF': 'PU',
#    'AGG_METHOD': None,
#    'DECIMALS': None,
#    'COMMENT_TS': None,
#    'DATA_SOURCE': None,
#    'LATEST_DATA': True,
#    'DATABASE_ID': 'WEF_TTDI',
#    'INDICATOR': 'WEF_TTDI_EOSQ057',
#    'REF_AREA': 'GBR',
#    'SEX': '_T',
#    'AGE': '_T',
#    'URBANISATION': '_T',
#    'COMP_BREAKDOWN_1': 'WEF_TTDI_VAL',
#    'COMP_BREAKDOWN_2': '_Z',
#    'COMP_BREAKDOWN_3': '_Z',
#    'TIME_PERIOD': '2024',
#    'FREQ': 'A',
#    'UNIT_MEASURE': 'IX_1T7',
#    'UNIT_TYPE': None}]}

# %%
data = data["value"]
len(data)
# Out:
# 1000

# %%
names_list = [
    'Albania',
    'Algeria',
    'Angola',
    'Argentina',
    'Armenia',
    'Australia',
    'Austria',
    'Azerbaijan',
    'Bahrain',
    'Bangladesh',
    'Barbados',
    'Belgium',
    'Benin',
    'Bolivia',
    'Bosnia and Herzegovina',
    'Botswana',
    'Brazil',
    'Bulgaria',
    'Cambodia',
    'Cameroon',
    'Canada',
    'Chile',
    'China',
    'Colombia',
    'Costa Rica',
    "Cote d'Ivoire",
    'Croatia',
    'Cyprus',
    'Czechia',
    'Denmark',
    'Dominican Republic',
    'Ecuador',
    'Egypt, Arab Rep.',
    'El Salvador',
    'Estonia',
    'Finland',
    'France',
    'Georgia',
    'Germany',
    'Ghana',
    'Greece',
    'Guatemala',
    'Honduras',
    'Hungary',
    'Iceland',
    'India',
    'Indonesia',
    'Iran, Islamic Rep.',
    'Ireland',
    'Israel',
    'Italy',
    'Jamaica',
    'Japan',
    'Jordan',
    'Kazakhstan',
    'Kenya',
    'Korea, Rep.',
    'Kuwait',
    'Kyrgyz Republic',
    'Lao PDR',
    'Latvia',
    'Lebanon',
    'Lithuania',
    'Luxembourg',
    'North Macedonia',
    'Malawi',
    'Malaysia',
    'Mali',
    'Malta',
    'Mauritius',
    'Mexico',
    'Moldova',
    'Mongolia',
    'Montenegro',
    'Morocco',
    'Namibia',
    'Nepal',
    'Netherlands',
    'New Zealand',
    'Nicaragua',
    'Nigeria',
    'Oman',
    'Pakistan',
    'Panama',
    'Paraguay',
    'Peru',
    'Philippines',
    'Poland',
    'Portugal',
    'Qatar',
    'Romania',
    'Rwanda',
    'Saudi Arabia',
    'Senegal',
    'Serbia',
    'Sierra Leone',
    'Singapore',
    'Slovak Republic',
    'Slovenia',
    'South Africa',
    'Spain',
    'Sri Lanka',
    'Sweden',
    'Switzerland',
    'Tajikistan',
    'Tanzania',
    'Thailand',
    'Trinidad and Tobago',
    'Tunisia',
    'Turkiye',
    'United Arab Emirates',
    'United Kingdom',
]

# %%
def cleaned_data(data, year, name_list, EU_countries_list): 

    cleaned_dict = {}

    for item in data:
        if item.get('COMP_BREAKDOWN_1') == 'WEF_TTDI_VAL':  
            ref_area = item.get('REF_AREA')
            obs_value = item.get('OBS_VALUE')
            if item.get('TIME_PERIOD') == year and ref_area not in cleaned_dict:
                cleaned_dict[ref_area] = year, obs_value 
    
    updated_dict = dict(zip(name_list, cleaned_dict.values()))

    filtered_dict = {k: v for k, v in updated_dict.items() if k in EU_countries_list}

    rows = [(k, v[0], v[1]) for k, v in filtered_dict.items()]

    df_country = pd.DataFrame(rows, columns=['Country', 'Year', 'Score'])

    return df_country

# %%
data_24 = cleaned_data(data, '2024', names_list, EU_countries_list)
data_21 = cleaned_data(data, '2021', names_list, EU_countries_list)
data_19 = cleaned_data(data, '2019', names_list, EU_countries_list)
data_19
# Out:
#             Country  Year    Score
# 0           Austria  2019  5.88628
# 1           Belgium  2019  4.38674
# 2          Bulgaria  2019  3.51939
# 3           Croatia  2019  5.49288
# 4            Cyprus  2019  5.22057
# 5           Czechia  2019  3.94541
# 6           Denmark  2019  5.54639
# 7           Estonia  2019  4.68131
# 8           Finland  2019  5.26363
# 9            France  2019  5.95999
# 10          Germany  2019  5.45541
# 11           Greece  2019  4.73268
# 12          Hungary  2019  3.88925
# 13          Ireland  2019  4.47557
# 14            Italy  2019   4.3856
# 15           Latvia  2019  3.45011
# 16        Lithuania  2019  4.70477
# 17       Luxembourg  2019  5.33887
# 18            Malta  2019  3.24031
# 19      Netherlands  2019   6.1782
# 20           Poland  2019  4.13832
# 21         Portugal  2019  6.05215
# 22          Romania  2019  2.96465
# 23  Slovak Republic  2019  3.96468
# 24         Slovenia  2019  4.66181
# 25            Spain  2019  5.62898
# 26           Sweden  2019  5.56854

# %%
alldata = pd.concat([data_19, data_21, data_24], ignore_index=True)

alldata
# Out:
#             Country  Year    Score
# 0           Austria  2019  5.88628
# 1           Belgium  2019  4.38674
# 2          Bulgaria  2019  3.51939
# 3           Croatia  2019  5.49288
# 4            Cyprus  2019  5.22057
# ..              ...   ...      ...
# 76          Romania  2024  3.49493
# 77  Slovak Republic  2024  4.08356
# 78         Slovenia  2024  4.63518
# 79            Spain  2024  5.53602
# 80           Sweden  2024  5.46551
#
# [81 rows x 3 columns]

# %%
Countries = alldata['Country']
Years = alldata['Year']
Value = alldata['Score']

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter(df, x=Countries, y=Value, color= Years)
fig.show()
